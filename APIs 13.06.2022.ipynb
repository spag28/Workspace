# %%
# !pip install requests

# %%
import requests

# %%
data = requests.get("http://api.open-notify.org/iss-now.json")

# %%
print(data)
# Out:
# <Response [200]>

# %%
#200 is good, means eveything is ok. anything starting with 2 is alright. 4 and 5 is not good.

# %%
data.json()
# Out:
# {'iss_position': {'longitude': '69.9226', 'latitude': '32.3371'},
#  'timestamp': 1655714945,
#  'message': 'success'}

# %%
type(data.json())
# Out:
# dict

# %%
#Parsing
data['iss_position']['longitude']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7860/2245760559.py in <module>
#       1 #Parsing
# ----> 2 data['iss_position']['longitude']
#
# TypeError: 'Response' object is not subscriptable

# %%
print(data)
# Out:
# <Response [200]>

# %%
data1 = data.json()

# %%
data1['iss_position']['longitude']
# Out:
# '69.9226'

# %%
data1['iss_position']
# Out:
# {'longitude': '69.9226', 'latitude': '32.3371'}

# %%
# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&apikey=MJJULQ2LBSJJVTWV'
r = requests.get(url)
dataalpha = r.json()

print(dataalpha)
# Out:
# {'Meta Data': {'1. Information': 'Intraday (5min) open, high, low, close prices and volume', '2. Symbol': 'IBM', '3. Last Refreshed': '2022-06-17 19:35:00', '4. Interval': '5min', '5. Output Size': 'Compact', '6. Time Zone': 'US/Eastern'}, 'Time Series (5min)': {'2022-06-17 19:35:00': {'1. open': '135.4800', '2. high': '135.4800', '3. low': '135.4800', '4. close': '135.4800', '5. volume': '300'}, '2022-06-17 18:45:00': {'1. open': '135.5000', '2. high': '135.5000', '3. low': '135.5000', '4. close': '135.5000', '5. volume': '650'}, '2022-06-17 17:55:00': {'1. open': '135.0200', '2. high': '135.0200', '3. low': '135.0200', '4. close': '135.0200', '5. volume': '3301'}, '2022-06-17 17:35:00': {'1. open': '135.0400', '2. high': '135.0400', '3. low': '135.0400', '4. close': '135.0400', '5. volume': '301'}, '2022-06-17 17:15:00': {'1. open': '135.0400', '2. high': '135.0400', '3. low': '135.0400', '4. close': '135.0400', '5. volume': '400'}, '2022-06-17 17:10:00': {'1. open': '135.0700', '2
# ...

# %%
import pandas as pd

# %%
pd.DataFrame(dataalpha)
# Out:
#                                                              Meta Data  \
# 1. Information       Intraday (5min) open, high, low, close prices ...
# 2. Symbol                                                          IBM
# 3. Last Refreshed                                  2022-06-17 19:35:00
# 4. Interval                                                       5min
# 5. Output Size                                                 Compact
# ...                                                                ...
# 2022-06-17 08:45:00                                                NaN
# 2022-06-17 08:35:00                                                NaN
# 2022-06-17 08:30:00                                                NaN
# 2022-06-17 08:20:00                                                NaN
# 2022-06-17 08:10:00                                                NaN
#
#                                                     Time Series (5min)
# ...

# %%
pd.DataFrame.(dataalpha.items())
# Out:
#   File "C:\Users\spagg\AppData\Local\Temp/ipykernel_7860/5837613.py", line 1
#     pd.DataFrame.(dataalpha.items())
#                  ^
# SyntaxError: invalid syntax

# %%
d=r.json()

# %%
d['Time Series (5min)']
# Out:
# {'2022-06-17 19:35:00': {'1. open': '135.4800',
#   '2. high': '135.4800',
#   '3. low': '135.4800',
#   '4. close': '135.4800',
#   '5. volume': '300'},
#  '2022-06-17 18:45:00': {'1. open': '135.5000',
#   '2. high': '135.5000',
#   '3. low': '135.5000',
#   '4. close': '135.5000',
#   '5. volume': '650'},
#  '2022-06-17 17:55:00': {'1. open': '135.0200',
#   '2. high': '135.0200',
#   '3. low': '135.0200',
#   '4. close': '135.0200',
#   '5. volume': '3301'},
#  '2022-06-17 17:35:00': {'1. open': '135.0400',
#   '2. high': '135.0400',
#   '3. low': '135.0400',
#   '4. close': '135.0400',
#   '5. volume': '301'},
#  '2022-06-17 17:15:00': {'1. open': '135.0400',
#   '2. high': '135.0400',
#   '3. low': '135.0400',
#   '4. close': '135.0400',
#   '5. volume': '400'},
#  '2022-06-17 17:10:00': {'1. open': '135.0700',
#   '2. high': '135.0700',
#   '3. low': '135.0500',
#   '4. close': '135.0500',
#   '5. volume': '1305'},
#  '2022-06-17 17:05:00': {'1. open': '135.2699',
# ...

# %%
pd.DataFrame(d['Time Series (5min)'])
# Out:
#           2022-06-17 19:35:00 2022-06-17 18:45:00 2022-06-17 17:55:00  \
# 1. open              135.4800            135.5000            135.0200
# 2. high              135.4800            135.5000            135.0200
# 3. low               135.4800            135.5000            135.0200
# 4. close             135.4800            135.5000            135.0200
# 5. volume                 300                 650                3301
#
#           2022-06-17 17:35:00 2022-06-17 17:15:00 2022-06-17 17:10:00  \
# 1. open              135.0400            135.0400            135.0700
# 2. high              135.0400            135.0400            135.0700
# 3. low               135.0400            135.0400            135.0500
# 4. close             135.0400            135.0400            135.0500
# 5. volume                 301                 400                1305
#
#           2022-06-17 17:05:00 2022-06-17 17:00:00 2022-06-17 16:30:00  \
# ...

# %%
pd.DataFrame(d['Time Series (5min)']).T
# Out:
#                       1. open   2. high    3. low  4. close 5. volume
# 2022-06-17 19:35:00  135.4800  135.4800  135.4800  135.4800       300
# 2022-06-17 18:45:00  135.5000  135.5000  135.5000  135.5000       650
# 2022-06-17 17:55:00  135.0200  135.0200  135.0200  135.0200      3301
# 2022-06-17 17:35:00  135.0400  135.0400  135.0400  135.0400       301
# 2022-06-17 17:15:00  135.0400  135.0400  135.0400  135.0400       400
# ...                       ...       ...       ...       ...       ...
# 2022-06-17 08:45:00  136.0000  136.0000  135.7400  135.7400       827
# 2022-06-17 08:35:00  136.2500  136.2500  136.2499  136.2499       454
# 2022-06-17 08:30:00  136.2499  136.2499  136.2499  136.2499       105
# 2022-06-17 08:20:00  136.2500  136.2500  136.2500  136.2500       173
# 2022-06-17 08:10:00  136.2500  136.2500  136.2500  136.2500       100
#
# [100 rows x 5 columns]
