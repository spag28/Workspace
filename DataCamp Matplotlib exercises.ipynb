# %%
import pandas as pd

# %%
austin_weather=pd.read_csv(r'C:\Users\spagg\Documents\Python\12. Matplotlib\austin_weather.csv')

# %%
austin_weather.head()
# Out:
#        STATION                                           NAME  DATE  \
# 0  USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     1
# 1  USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     2
# 2  USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     3
# 3  USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     4
# 4  USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     5
#
#    MLY-CLDD-BASE45  MLY-CLDD-BASE50  MLY-CLDD-BASE55  MLY-CLDD-BASE57  \
# 0              190              103               50               35
# 1              228              132               68               49
# 2              446              306              185              146
# 3              668              519              373              318
# 4              936              781              626              564
#
#    MLY-CLDD-BASE60  MLY-CLDD-BASE70  MLY-CLDD-BASE72  ...  \
# 0               18                1            -7777  ...
# ...

# %%
seattle_weather=pd.read_csv(r'C:\Users\spagg\Documents\Python\12. Matplotlib\seattle_weather.csv')

# %%
climate_change=pd.read_csv(r'C:\Users\spagg\Documents\Python\12. Matplotlib\climate_change.csv')

# %%
summer=pd.read_csv(r'C:\Users\spagg\Documents\Python\12. Matplotlib\summer2016.csv')

# %%
medals=pd.read_csv(r'C:\Users\spagg\Documents\Python\12. Matplotlib\medals_by_country_2016.csv')

# %%
medals.head()
# Out:
#       Unnamed: 0  Bronze  Gold  Silver
# 0  United States      67   137      52
# 1        Germany      67    47      43
# 2  Great Britain      26    64      55
# 3         Russia      35    50      28
# 4          China      35    44      30

# %%
seattle_weather.head()
# Out:
#        STATION                 NAME  DATE  MLY-CLDD-BASE45  MLY-CLDD-BASE50  \
# 0  USC00456295  PALMER 3 ESE, WA US     1             13.0              1.0
# 1  USC00456295  PALMER 3 ESE, WA US     2             23.0              3.0
# 2  USC00456295  PALMER 3 ESE, WA US     3             50.0             11.0
# 3  USC00456295  PALMER 3 ESE, WA US     4            108.0             40.0
# 4  USC00456295  PALMER 3 ESE, WA US     5            255.0            130.0
#
#    MLY-CLDD-BASE55  MLY-CLDD-BASE57  MLY-CLDD-BASE60  MLY-CLDD-BASE70  \
# 0          -7777.0              0.0              0.0              0.0
# 1          -7777.0          -7777.0              0.0              0.0
# 2              1.0          -7777.0          -7777.0              0.0
# 3             12.0              7.0              3.0          -7777.0
# 4             56.0             38.0             19.0              1.0
#
#    MLY-CLDD-BASE72  ...  MLY-TMIN-AVGNDS-LSTH060  MLY-TMIN-AVGNDS-LSTH070  \
# ...

# %%
seattle_weather["MLY-TAVG-NORMAL"]
# Out:
# 0      39.3
# 1      40.7
# 2      43.8
# 3      47.4
# 4      53.1
#        ...
# 199    66.7
# 200    61.5
# 201    52.9
# 202    45.5
# 203    40.3
# Name: MLY-TAVG-NORMAL, Length: 204, dtype: float64

# %%
seattle_weather["DATE"]
# Out:
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
#        ..
# 199     8
# 200     9
# 201    10
# 202    11
# 203    12
# Name: DATE, Length: 204, dtype: int64

# %%
import matplotlib.pyplot as plt

fig,ax = plt.subplots()

plt.show()

# %%
fig,ax = plt.subplots()
ax.plot(seattle_weather["DATE"],seattle_weather["MLY-PRCP-NORMAL"])
ax.plot(austin_weather["DATE"],austin_weather["MLY-PRCP-NORMAL"])
plt.show()

# %%
fig,ax = plt.subplots()
ax.plot(austin_weather["DATE"],austin_weather["MLY-PRCP-NORMAL"])
plt.show()

# %%
fig,ax = plt.subplots()
ax.plot(austin_weather["DATE"],austin_weather["MLY-PRCP-NORMAL"],
marker = "v",
linestyle = "--",
color = "y")
plt.show()
